# %%
# !pip install networkx
import networkx as nx

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/biography_cs.csv')

# %%
for index, row in df.iterrows():
    G.add_node(row['Name'], category=row['Category'], content=row['Content'])
nx.draw(G, with_labels=True, font_weight='bold')
plt.show()

# %%
import json
graph_dict = nx.node_link_data(G)
with open('csknowledgegraph.json', 'w') as json_file:
    json.dump(graph_dict, json_file, indent=4)

print("Knowledge graph saved as 'csknowledgegraph.json'")
# Out:
# Knowledge graph saved as 'csknowledgegraph.json'

# %%
df = pd.read_csv('/content/biography_sculptor.csv')
for index, row in df.iterrows():
    G.add_node(row['Name'], category=row['Category'], content=row['Content'])
nx.draw(G, with_labels=True, font_weight='bold')
plt.show()

# %%
import json
graph_dict = nx.node_link_data(G)
with open('sculptorkgraph.json', 'w') as json_file:
    json.dump(graph_dict, json_file, indent=4)

print("Knowledge graph saved as 'sculptorkgraph.json'")
# Out:
# Knowledge graph saved as 'sculptorkgraph.json'
